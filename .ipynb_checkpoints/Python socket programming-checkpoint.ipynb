# %%
from socket import *
import socket

# %%
s = socket.socket(family=AF_INET,type=SOCK_STREAM,port=0)

# %%
import socket
import sys
try:
    sockfd = socket.socket(socket.AF_INET,socket.SOCK_STREAM)
except socket.error as err:
    print('Failed to create a socket')
    print('Reason'+str(err))
    sys.exit()
print('Socket Created.')

target_host = input('Enter the target host name to connect')
target_port = input('Enter the target port')

try:
    sock.connect(target_host,int(target_port))
    print('socket connected to: '+target_host+target_port)
    sock.shutdown(2)
except socket.error as err:
    print("Failed to connect to %s on port %s"%(target_host,target_port))
    print("Reason: %s"%str(err))
    sys.exit()

# %%
from PIL import ImageTk, Image
from tkinter import Tk, Label, Button

root = Tk()
root.title('Zoom clone')
iconpath = r"C:\Users\KIIT\Desktop\5th sem materials\Project\zoom.ico"
root.iconbitmap(iconpath)
root.mainloop()

# %%
from vidstream import *
import tkinter as tk
import socket
import threading
import requests

local_ip_address = socket.gethostbyname(socket.gethostname())
#print(local_ip_address)
server = StreamingServer(local_ip_address, 9999)
reciever = AudioReceiver(local_ip_address, 8888)

def start_listening():
    t1 = threading.Thread(target=server.start_server).start()
    t2 = threading.Thread(target=reciever.start_server).start()
    
def start_camera_stream():
    # we have to define a client in the function everytime 
    # we click the button it starts a new camera stream 
    #to get the ip in right format without the backslash at the end
    # end-1c will read until the end but not the backslash
                                              #line.column -1.0
    camera_client = CameraClient(text_target_ip.get(1.0,'end-1c'),7777)
    t3 = threading.Thread(target=camera_client.start_stream).start()
    
    
def start_screen_sharing():
    screen_client = ScreenShareClient(text_target_ip.get(1.0,'end-1c'),7777)
    t4 = threading.Thread(target=screen_client.start_stream).start()
    
    
def start_audio_stream():
    audio_sender = AudioSender(text_target_ip.get(1.0,'end-1c'),6666)
    # going to connect to same ip but different port
    # bcoz the streaming server for vdo data is on one port & audio reciever on another port
    t5 = threading.Thread(target=audio_sender.start_stream).start()

# %%
import threading #threading is used to efficiently use the downtime
import time

done = False




def worker():
    counter = 0
    while not done:
        time.sleep(1)
        counter += 1
        print(counter)

        
# passing worker function as object 
# define a thread 
threading.Thread(target=worker).start()



input("Press enter to quit")
done = True

# %% [markdown]
# It's not necessary for the port numbers to be the same. In a network application, different ports are used to distinguish between different services or purposes. In this case, port 9999 is used for the server to manage incoming connections and requests, while port 7777 is used specifically for streaming camera video and screen sharing. The specific port numbers are chosen by the developer to meet the application's requirements and design

# %%
from vidstream import *
import tkinter as tk
import socket
import threading
import requests

local_ip_address = socket.gethostbyname(socket.gethostname())
#print(local_ip_address)
server = StreamingServer(local_ip_address, 9999)
reciever = AudioReceiver(local_ip_address, 8888)

def start_listening():
    t1 = threading.Thread(target=server.start_server).start()
    t2 = threading.Thread(target=reciever.start_server).start()
    
def start_camera_stream():
    camera_client = CameraClient(text_target_ip.get(1.0,'end-1c'),7777)
    t3 = threading.Thread(target=camera_client.start_stream).start()
    
    
def start_screen_sharing():
    screen_client = ScreenShareClient(text_target_ip.get(1.0,'end-1c'),7777)
    t4 = threading.Thread(target=screen_client.start_stream).start()
    
    
def start_audio_stream():
    audio_sender = AudioSender(text_target_ip.get(1.0,'end-1c'),6666)
    t5 = threading.Thread(target=audio_sender.start_stream).start()

# %%
import tkinter as tk
from PIL import Image, ImageTk

# Functions for the different options
def start_listening():
    target_ip = target_ip_entry.get()
    pass

def start_camera_stream():
    target_ip = target_ip_entry.get()
    pass

def start_screen_share():
    target_ip = target_ip_entry.get()
    pass

def start_audio_stream():
    target_ip = target_ip_entry.get()
    pass

# Main window
root = tk.Tk()
root.title("Zoom Clone")

# Icon
#icon_image = Image.open("zoom.png")
#icon_photo = ImageTk.PhotoImage(icon_image)
#root.iconphoto(True, icon_photo)

iconpath = r"C:\Users\KIIT\Desktop\5th sem materials\Project\zoom.ico"
root.iconbitmap(iconpath)


# Entry for Target IP
target_ip_label = tk.Label(root, text="Enter Target IP:")
target_ip_label.grid(row=0, column=0, padx=5, pady=5)
target_ip_entry = tk.Entry(root)
target_ip_entry.grid(row=0, column=1, padx=5, pady=5)

# Create a 2x2 grid for image buttons
button_width = 70
button_height = 70

listening_image = Image.open("play.png")
listening_photo = ImageTk.PhotoImage(listening_image)

camera_image = Image.open("camera.png")
camera_photo = ImageTk.PhotoImage(camera_image)

screen_share_image = Image.open("screen.png")
screen_share_photo = ImageTk.PhotoImage(screen_share_image)

audio_stream_image = Image.open("mic.png")
audio_stream_photo = ImageTk.PhotoImage(audio_stream_image)

listening_button = tk.Button(root, image=listening_photo, command=start_listening, width=button_width, height=button_height)
camera_stream_button = tk.Button(root, image=camera_photo, command=start_camera_stream, width=button_width, height=button_height)
screen_share_button = tk.Button(root, image=screen_share_photo, command=start_screen_share, width=button_width, height=button_height)
audio_stream_button = tk.Button(root, image=audio_stream_photo, command=start_audio_stream, width=button_width, height=button_height)

listening_button.grid(row=1, column=0, padx=5, pady=5)
camera_stream_button.grid(row=1, column=1, padx=5, pady=5)
screen_share_button.grid(row=2, column=0, padx=5, pady=5)
audio_stream_button.grid(row=2, column=1, padx=5, pady=5)

root.mainloop()

# %%
import tkinter as tk
from PIL import Image, ImageTk
from vidstream import *
import socket
import threading
import requests

local_ip_address = socket.gethostbyname(socket.gethostname())
#print(local_ip_address)
server = StreamingServer(local_ip_address, 20000)
reciever = AudioReceiver(local_ip_address, 40000)
# Functions for the different options
def start_listening():
    t1 = threading.Thread(target=server.start_server).start()
    t2 = threading.Thread(target=reciever.start_server).start()
    
def start_camera_stream():
    camera_client = CameraClient(text_target_ip.get(1.0,'end-1c'),7777)
    t3 = threading.Thread(target=camera_client.start_stream).start()
    
    
def start_screen_sharing():
    screen_client = ScreenShareClient(text_target_ip.get(1.0,'end-1c'),7777)
    t4 = threading.Thread(target=screen_client.start_stream).start()
    
    
def start_audio_stream():
    audio_sender = AudioSender(text_target_ip.get(1.0,'end-1c'),6666)
    t5 = threading.Thread(target=audio_sender.start_stream).start()

# Main window
root = tk.Tk()
root.title("Zoom Clone")

# Icon
#icon_image = Image.open("zoom.png")
#icon_photo = ImageTk.PhotoImage(icon_image)
#root.iconphoto(True, icon_photo)

# Icon
iconpath = r"C:\Users\KIIT\Desktop\5th sem materials\Project\zoom.ico"
root.iconbitmap(iconpath)

# Entry for Target IP
target_ip_label = tk.Label(root, text="Enter Target IP:")
target_ip_label.grid(row=0, column=0, padx=5, pady=5)
target_ip_entry = tk.Entry(root)
target_ip_entry.grid(row=0, column=1, padx=5, pady=5)

# Create a 2x2 grid for image buttons
button_width = 70
button_height = 70

listening_image = Image.open("play.png")
listening_image = listening_image.resize((button_width,button_height))
listening_photo = ImageTk.PhotoImage(listening_image)

camera_image = Image.open("camera.png")
camera_image = camera_image.resize((button_width,button_height))
camera_photo = ImageTk.PhotoImage(camera_image)

screen_share_image = Image.open("screen.png")
screen_share_image = screen_share_image.resize((button_width,button_height))
screen_share_photo = ImageTk.PhotoImage(screen_share_image)

audio_stream_image = Image.open("mic.png")
audio_stream_image = audio_stream_image.resize((button_width,button_height))
audio_stream_photo = ImageTk.PhotoImage(audio_stream_image)

# Store PhotoImage objects in a list to prevent garbage collection
photo_images = [listening_photo, camera_photo, screen_share_photo, audio_stream_photo]

listening_button = tk.Button(root, image=photo_images[0], command=start_listening, width=button_width, height=button_height,compound=tk.TOP)
camera_stream_button = tk.Button(root, image=photo_images[1], command=start_camera_stream, width=button_width, height=button_height,compound=tk.TOP)
screen_share_button = tk.Button(root, image=photo_images[2], command=start_screen_share, width=button_width, height=button_height,compound=tk.TOP)
audio_stream_button = tk.Button(root, image=photo_images[3], command=start_audio_stream, width=button_width, height=button_height,compound=tk.TOP)

listening_button.grid(row=1, column=0, padx=5, pady=5)
camera_stream_button.grid(row=1, column=1, padx=5, pady=5)
screen_share_button.grid(row=2, column=0, padx=5, pady=5)
audio_stream_button.grid(row=2, column=1, padx=5, pady=5)

root.mainloop()

# %%
#final incorrect
import tkinter as tk
from PIL import Image, ImageTk
from vidstream import *
import socket
import threading
import requests

local_ip_address = socket.gethostbyname(socket.gethostname())
#print(local_ip_address)
server = StreamingServer(local_ip_address, 42100)
reciever = AudioReceiver(local_ip_address, 30300)

def start_listening():
    t1 = threading.Thread(target=server.start_server).start()
    t2 = threading.Thread(target=reciever.start_server).start()
    
    
def start_camera_stream():
    target_ip = target_ip_entry.get()
    camera_client = CameraClient(target_ip, 7777)
    t3 = threading.Thread(target=camera_client.start_stream).start()

def start_screen_sharing():
    target_ip = target_ip_entry.get()
    screen_client = ScreenShareClient(target_ip, 7777)
    t4 = threading.Thread(target=screen_client.start_stream).start()
    
def start_audio_stream():
    target_ip = target_ip_entry.get()
    audio_sender = AudioSender(target_ip, 6666)
    t5 = threading.Thread(target=audio_sender.start_stream).start()


#def start_camera_stream():
   # camera_client = CameraClient(target_ip_entry.get(1.0,'end-1c'),7777)
    #t3 = threading.Thread(target=camera_client.start_stream).start()
    
    
#def start_screen_sharing():
 #   screen_client = ScreenShareClient(target_ip_entry.get(1.0,'end-1c'),7777)
  #  t4 = threading.Thread(target=screen_client.start_stream).start()
    
    
#def start_audio_stream():
 #   audio_sender = AudioSender(target_ip_entry.get(1.0,'end-1c'),6666)
  #  t5 = threading.Thread(target=audio_sender.start_stream).start()

# Main window
root = tk.Tk()
root.title("Zoom Clone")

# Icon
#icon_image = Image.open("zoom.png")
#icon_photo = ImageTk.PhotoImage(icon_image)
#root.iconphoto(True, icon_photo)

# Icon
iconpath = r"C:\Users\KIIT\Desktop\5th sem materials\Project\zoom.ico"
root.iconbitmap(iconpath)

# Entry for Target IP
target_ip_label = tk.Label(root, text="Enter Target IP:")
target_ip_label.grid(row=0, column=0, padx=5, pady=5)
target_ip_entry = tk.Entry(root)
target_ip_entry.grid(row=0, column=1, padx=5, pady=5)

# Create a 2x2 grid for image buttons
button_width = 70
button_height = 70

listening_image = Image.open("play.png")
listening_image = listening_image.resize((button_width, button_height))
listening_photo = ImageTk.PhotoImage(listening_image)

camera_image = Image.open("camera.png")
camera_image = camera_image.resize((button_width, button_height))
camera_photo = ImageTk.PhotoImage(camera_image)

screen_share_image = Image.open("screen.png")
screen_share_image = screen_share_image.resize((button_width, button_height))
screen_share_photo = ImageTk.PhotoImage(screen_share_image)

audio_stream_image = Image.open("mic.png")
audio_stream_image = audio_stream_image.resize((button_width, button_height))
audio_stream_photo = ImageTk.PhotoImage(audio_stream_image)

listening_button = tk.Button(root, image=listening_photo, command=start_listening, width=button_width, height=button_height, compound=tk.TOP)
camera_stream_button = tk.Button(root, image=camera_photo, command=start_camera_stream, width=button_width, height=button_height, compound=tk.TOP)
screen_share_button = tk.Button(root, image=screen_share_photo, command=start_screen_sharing, width=button_width, height=button_height, compound=tk.TOP)
audio_stream_button = tk.Button(root, image=audio_stream_photo, command=start_audio_stream, width=button_width, height=button_height, compound=tk.TOP)

listening_button.grid(row=1, column=0, padx=5, pady=5)
camera_stream_button.grid(row=1, column=1, padx=5, pady=5)
screen_share_button.grid(row=2, column=0, padx=5, pady=5)
audio_stream_button.grid(row=2, column=1, padx=5, pady=5)

root.mainloop()

# %%
#chatgpt
import tkinter as tk
from PIL import Image, ImageTk
from vidstream import *
import socket
import threading
import requests

# Function to get the local IP address
def get_local_ip_address():
    try:
        # Create a temporary socket to get the local IP address
        temp_socket = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
        temp_socket.connect(("8.8.8.8", 80))
        local_ip = temp_socket.getsockname()[0]
        temp_socket.close()
        return local_ip
    except Exception as e:
        print("Error getting local IP address:", e)
        return "127.0.0.1"

local_ip_address = get_local_ip_address()

# Function to start the server with dynamic port assignment
def start_listening():
    global server
    global reciever
    server = StreamingServer(local_ip_address, 43100)  # Use a fixed port for server
    reciever = AudioReceiver(local_ip_address, 37300)  # Use a fixed port for audio receiver
    t1 = threading.Thread(target=server.start_server)
    t2 = threading.Thread(target=reciever.start_server)
    t1.start()
    t2.start()

def start_camera_stream():
    target_ip = target_ip_entry.get()
    camera_client = CameraClient(target_ip, 7777)  # Use a fixed port for camera client
    t3 = threading.Thread(target=camera_client.start_stream)
    t3.start()

def start_screen_sharing():
    target_ip = target_ip_entry.get()
    screen_client = ScreenShareClient(target_ip, 7777)  # Use a fixed port for screen sharing client
    t4 = threading.Thread(target=screen_client.start_stream)
    t4.start()

def start_audio_stream():
    target_ip = target_ip_entry.get()
    audio_sender = AudioSender(target_ip, 6666)  # Use a fixed port for audio sender
    t5 = threading.Thread(target=audio_sender.start_stream)
    t5.start()

root = tk.Tk()
root.title("Zoom Clone")

# ...

# Use dynamic port assignment for the server and audio receiver
listening_button = tk.Button(root, image=listening_photo, command=start_listening, width=button_width, height=button_height, compound=tk.TOP)

# ...

root.mainloop()

# %%
#chatgpt
import tkinter as tk
from PIL import Image, ImageTk
from vidstream import *
import socket
import threading

# Function to get the local IP address
def get_local_ip_address():
    try:
        # Create a temporary socket to get the local IP address
        temp_socket = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
        temp_socket.connect(("8.8.8.8", 80))
        local_ip = temp_socket.getsockname()[0]
        temp_socket.close()
        return local_ip
    except Exception as e:
        print("Error getting local IP address:", e)
        return "127.0.0.1"

local_ip_address = get_local_ip_address()

# Function to start the server with dynamic port assignment
def start_listening():
    global server
    global reciever
    server = StreamingServer(local_ip_address, 43100)  # Use a fixed port for server
    reciever = AudioReceiver(local_ip_address, 37300)  # Use a fixed port for audio receiver
    t1 = threading.Thread(target=server.start_server)
    t2 = threading.Thread(target=reciever.start_server)
    t1.start()
    t2.start()

def start_camera_stream():
    target_ip = target_ip_entry.get()
    camera_client = CameraClient(target_ip, 7777)  # Use a fixed port for camera client
    t3 = threading.Thread(target=camera_client.start_stream)
    t3.start()

def start_screen_sharing():
    target_ip = target_ip_entry.get()
    screen_client = ScreenShareClient(target_ip, 7777)  # Use a fixed port for screen sharing client
    t4 = threading.Thread(target=screen_client.start_stream)
    t4.start()

def start_audio_stream():
    target_ip = target_ip_entry.get()
    audio_sender = AudioSender(target_ip, 6666)  # Use a fixed port for audio sender
    t5 = threading.Thread(target=audio_sender.start_stream)
    t5.start()

# Create the main window
root = tk.Tk()
root.title("Zoom Clone")

# Define image references as global variables
listening_photo = None
camera_photo = None
screen_share_photo = None
audio_stream_photo = None

# Function to load images and keep references
def load_images():
    global listening_photo, camera_photo, screen_share_photo, audio_stream_photo
    listening_image = Image.open("play.png")
    listening_image = listening_image.resize((70, 70))
    listening_photo = ImageTk.PhotoImage(listening_image)

    camera_image = Image.open("camera.png")
    camera_image = camera_image.resize((70, 70))
    camera_photo = ImageTk.PhotoImage(camera_image)

    screen_share_image = Image.open("screen.png")
    screen_share_image = screen_share_image.resize((70, 70))
    screen_share_photo = ImageTk.PhotoImage(screen_share_image)

    audio_stream_image = Image.open("mic.png")
    audio_stream_image = audio_stream_image.resize((70, 70))
    audio_stream_photo = ImageTk.PhotoImage(audio_stream_image)

load_images()  # Load the images

# Entry for Target IP
target_ip_label = tk.Label(root, text="Enter Target IP:")
target_ip_label.grid(row=0, column=0, padx=5, pady=5)
target_ip_entry = tk.Entry(root)
target_ip_entry.grid(row=0, column=1, padx=5, pady=5)

# Create a 2x2 grid for image buttons
listening_button = tk.Button(root, image=listening_photo, command=start_listening, width=70, height=70, compound=tk.TOP)
camera_stream_button = tk.Button(root, image=camera_photo, command=start_camera_stream, width=70, height=70, compound=tk.TOP)
screen_share_button = tk.Button(root, image=screen_share_photo, command=start_screen_sharing, width=70, height=70, compound=tk.TOP)
audio_stream_button = tk.Button(root, image=audio_stream_photo, command=start_audio_stream, width=70, height=70, compound=tk.TOP)

listening_button.grid(row=1, column=0, padx=5, pady=5)
camera_stream_button.grid(row=1, column=1, padx=5, pady=5)
screen_share_button.grid(row=2, column=0, padx=5, pady=5)
audio_stream_button.grid(row=2, column=1, padx=5, pady=5)

root.mainloop()

# %%
import tkinter as tk
from PIL import Image, ImageTk
from vidstream import *
import socket
import threading

local_ip_address = socket.gethostbyname(socket.gethostname())

def start_listening():
    t1 = threading.Thread(target=server.start_server)
    t2 = threading.Thread(target=reciever.start_server)
    t1.start()
    t2.start()

def start_camera_stream():
    target_ip = target_ip_entry.get()
    camera_client = CameraClient(target_ip, 7777)
    t3 = threading.Thread(target=camera_client.start_stream)
    t3.start()

def start_screen_sharing():
    target_ip = target_ip_entry.get()
    screen_client = ScreenShareClient(target_ip, 7777)
    t4 = threading.Thread(target=screen_client.start_stream)
    t4.start()

def start_audio_stream():
    target_ip = target_ip_entry.get()
    audio_sender = AudioSender(target_ip, 6666)
    t5 = threading.Thread(target=audio_sender.start_stream)
    t5.start()

root = tk.Tk()
root.title("Zoom Clone")

iconpath = r"C:\Users\KIIT\Desktop\5th sem materials\Project\zoom.ico"
root.iconbitmap(iconpath)

target_ip_label = tk.Label(root, text="Enter Target IP:")
target_ip_label.grid(row=0, column=0, padx=5, pady=5)
target_ip_entry = tk.Entry(root)
target_ip_entry.grid(row=0, column=1, padx=5, pady=5)

# Create a 2x2 grid for image buttons
button_width = 70
button_height = 70

def load_images():
    listening_image = Image.open("play.png")
    listening_image = listening_image.resize((button_width, button_height))
    listening_photo = ImageTk.PhotoImage(listening_image)

    camera_image = Image.open("camera.png")
    camera_image = camera_image.resize((button_width, button_height))
    camera_photo = ImageTk.PhotoImage(camera_image)

    screen_share_image = Image.open("screen.png")
    screen_share_image = screen_share_image.resize((button_width, button_height))
    screen_share_photo = ImageTk.PhotoImage(screen_share_image)

    audio_stream_image = Image.open("mic.png")
    audio_stream_image = audio_stream_image.resize((button_width, button_height))
    audio_stream_photo = ImageTk.PhotoImage(audio_stream_image)

    return listening_photo, camera_photo, screen_share_photo, audio_stream_photo

listening_photo, camera_photo, screen_share_photo, audio_stream_photo = load_images()

listening_button = tk.Button(root, image=listening_photo, command=start_listening, width=button_width, height=button_height, compound=tk.TOP)
camera_stream_button = tk.Button(root, image=camera_photo, command=start_camera_stream, width=button_width, height=button_height, compound=tk.TOP)
screen_share_button = tk.Button(root, image=screen_share_photo, command=start_screen_sharing, width=button_width, height=button_height, compound=tk.TOP)
audio_stream_button = tk.Button(root, image=audio_stream_photo, command=start_audio_stream, width=button_width, height=button_height, compound=tk.TOP)

listening_button.grid(row=1, column=0, padx=5, pady=5)
camera_stream_button.grid(row=1, column=1, padx=5, pady=5)
screen_share_button.grid(row=2, column=0, padx=5, pady=5)
audio_stream_button.grid(row=2, column=1, padx=5, pady=5)

server = StreamingServer(local_ip_address, 43100)
reciever = AudioReceiver(local_ip_address, 37300)

root.mainloop()

# %%
import tkinter as tk
from PIL import Image, ImageTk
from vidstream import *
import socket
import threading

local_ip_address = socket.gethostbyname(socket.gethostname())

def start_listening():
    t1 = threading.Thread(target=server.start_server)
    t2 = threading.Thread(target=reciever.start_server)
    t1.start()
    t2.start()

def start_camera_stream():
    target_ip = target_ip_entry.get()
    camera_client = CameraClient(target_ip, 7777)
    t3 = threading.Thread(target=camera_client.start_stream)
    t3.start()

def start_screen_sharing():
    target_ip = target_ip_entry.get()
    screen_client = ScreenShareClient(target_ip, 7777)
    t4 = threading.Thread(target=screen_client.start_stream)
    t4.start()

def start_audio_stream():
    target_ip = target_ip_entry.get()
    audio_sender = AudioSender(target_ip, 6666)
    t5 = threading.Thread(target=audio_sender.start_stream)
    t5.start()

root = tk.Tk()
root.title("Zoom Clone")

iconpath = r"C:\Users\KIIT\Desktop\5th sem materials\Project\zoom.ico"
root.iconbitmap(iconpath)

target_ip_label = tk.Label(root, text="Enter Target IP:")
target_ip_label.grid(row=0, column=0, padx=5, pady=5)
target_ip_entry = tk.Entry(root)
target_ip_entry.grid(row=0, column=1, padx=5, pady=5)

button_width = 70
button_height = 70

# Create a function to load images
def load_images():
    listening_image = Image.open("play.png")
    listening_image = listening_image.resize((button_width, button_height))
    listening_photo = ImageTk.PhotoImage(listening_image)

    camera_image = Image.open("camera.png")
    camera_image = camera_image.resize((button_width, button_height))
    camera_photo = ImageTk.PhotoImage(camera_image)

    screen_share_image = Image.open("screen.png")
    screen_share_image = screen_share_image.resize((button_width, button_height))
    screen_share_photo = ImageTk.PhotoImage(screen_share_image)

    audio_stream_image = Image.open("mic.png")
    audio_stream_image = audio_stream_image.resize((button_width, button_height))
    audio_stream_photo = ImageTk.PhotoImage(audio_stream_image)

    return listening_photo, camera_photo, screen_share_photo, audio_stream_photo

listening_photo, camera_photo, screen_share_photo, audio_stream_photo = load_images()

# Define buttons after loading images
listening_button = tk.Button(root, image=listening_photo, command=start_listening, width=button_width, height=button_height, compound=tk.TOP)
camera_stream_button = tk.Button(root, image=camera_photo, command=start_camera_stream, width=button_width, height=button_height, compound=tk.TOP)
screen_share_button = tk.Button(root, image=screen_share_photo, command=start_screen_sharing, width=button_width, height=button_height, compound=tk.TOP)
audio_stream_button = tk.Button(root, image=audio_stream_photo, command=start_audio_stream, width=button_width, height=button_height, compound=tk.TOP)

listening_button.grid(row=1, column=0, padx=5, pady=5)
camera_stream_button.grid(row=1, column=1, padx=5, pady=5)
screen_share_button.grid(row=2, column=0, padx=5, pady=5)
audio_stream_button.grid(row=2, column=1, padx=5, pady=5)

server = StreamingServer(local_ip_address, 46100)
reciever = AudioReceiver(local_ip_address, 39300)

root.mainloop()

# %%
import tkinter as tk
from PIL import Image, ImageTk
from vidstream import *
import socket
import threading
import requests

local_ip_address = socket.gethostbyname(socket.gethostname())
server = StreamingServer(local_ip_address, 8681)  # Use a fixed port for the server
reciever = AudioReceiver(local_ip_address, 7882)  # Use a fixed port for audio receiver

def start_listening():
    t1 = threading.Thread(target=server.start_server)
    t2 = threading.Thread(target=reciever.start_server)
    t1.start()
    t2.start()

def start_camera_stream():
    target_ip = target_ip_entry.get()
    camera_client = CameraClient(target_ip, 7777)  # Use the same port for camera client
    t3 = threading.Thread(target=camera_client.start_stream)
    t3.start()

def start_screen_sharing():
    target_ip = target_ip_entry.get()
    screen_client = ScreenShareClient(target_ip, 7777)  # Use the same port for screen sharing client
    t4 = threading.Thread(target=screen_client.start_stream)
    t4.start()

def start_audio_stream():
    target_ip = target_ip_entry.get()
    audio_sender = AudioSender(target_ip, 6666)  # Use the same port for audio sender
    t5 = threading.Thread(target=audio_sender.start_stream)
    t5.start()

root = tk.Tk()
root.title("Zoom Clone")

iconpath = r"C:\Users\KIIT\Desktop\5th sem materials\Project\zoom.ico"
root.iconbitmap(iconpath)

target_ip_label = tk.Label(root, text="Enter Target Public IP:")
target_ip_label.grid(row=0, column=0, padx=5, pady=5)
target_ip_entry = tk.Entry(root)
target_ip_entry.grid(row=0, column=1, padx=5, pady=5)

button_width = 70
button_height = 70

def load_images():
    listening_image = Image.open("play.png")
    listening_image = listening_image.resize((button_width, button_height))
    listening_photo = ImageTk.PhotoImage(listening_image)

    camera_image = Image.open("camera.png")
    camera_image = camera_image.resize((button_width, button_height))
    camera_photo = ImageTk.PhotoImage(camera_image)

    screen_share_image = Image.open("screen.png")
    screen_share_image = screen_share_image.resize((button_width, button_height))
    screen_share_photo = ImageTk.PhotoImage(screen_share_image)

    audio_stream_image = Image.open("mic.png")
    audio_stream_image = audio_stream_image.resize((button_width, button_height))
    audio_stream_photo = ImageTk.PhotoImage(audio_stream_image)

    return listening_photo, camera_photo, screen_share_photo, audio_stream_photo

listening_photo, camera_photo, screen_share_photo, audio_stream_photo = load_images()

listening_button = tk.Button(root, image=listening_photo, command=start_listening, width=button_width, height=button_height, compound=tk.TOP)
camera_stream_button = tk.Button(root, image=camera_photo, command=start_camera_stream, width=button_width, height=button_height, compound=tk.TOP)
screen_share_button = tk.Button(root, image=screen_share_photo, command=start_screen_sharing, width=button_width, height=button_height, compound=tk.TOP)
audio_stream_button = tk.Button(root, image=audio_stream_photo, command=start_audio_stream, width=button_width, height=button_height, compound=tk.TOP)

listening_button.grid(row=1, column=0, padx=5, pady=5)
camera_stream_button.grid(row=1, column=1, padx=5, pady=5)
screen_share_button.grid(row=2, column=0, padx=5, pady=5)
audio_stream_button.grid(row=2, column=1, padx=5, pady=5)

root.mainloop()

# %%
import tkinter as tk
from PIL import Image, ImageTk
from vidstream import StreamingServer, AudioReceiver
import socket
import threading

local_ip_address = socket.gethostbyname(socket.gethostname())  # Use the local IP address of the server device
server = StreamingServer(local_ip_address, 8881)  # Use a fixed port for the server
reciever = AudioReceiver(local_ip_address, 7982)  # Use a fixed port for audio receiver

def start_listening():
    t1 = threading.Thread(target=server.start_server)
    t2 = threading.Thread(target=reciever.start_server)
    t1.start()
    t2.start()

root = tk.Tk()
root.title("Zoom Clone")

target_ip_label = tk.Label(root, text="Server IP (Your IP): " + local_ip_address)
target_ip_label.grid(row=0, column=0, padx=5, pady=5)

listening_button = tk.Button(root, text="Start Listening", command=start_listening)
listening_button.grid(row=1, column=0, padx=5, pady=5)

root.mainloop()

# %%
from vidstream import CameraClient
import threading

# Function to start the camera streaming
def start_camera_stream():
    client = CameraClient("192.168.29.118", 9991)  # Replace with the IP address of the server
    t = threading.Thread(target=client.start_stream)
    t.start()

# Start the camera stream
start_camera_stream()

# %%
from vidstream import CameraClient
import threading
from tkinter import * 
root = Tk()
# Function to start the camera streaming
def start_camera_stream():
    client = CameraClient("192.168.29.118", 9991)  # Replace with the IP address of the server
    t = threading.Thread(target=client.start_stream)
    t.start()

# Start the camera stream
#start_camera_stream()
btn = Button(root,text='start camera streaming',padx=5,pady=5,command=start_camera_stream)
btn.pack()
root.mainloop()

# %%
from vidstream import AudioSender
from tkinter import *
root = Tk()

# Function to start sending audio
def start_audio_sender():
    sender = AudioSender("192.168.29.118", 9992)  # Replace with the IP address of the receiver
    sender.start_stream()

# Start sending audio
#start_audio_sender()
btn = Button(root,text="start sending audio",padx=5,pady=5,command=start_audio_sender)
btn.pack()
root.mainloop()

# %%
from vidstream import AudioReceiver, AudioSender
import socket
import threading
from tkinter import *
root = Tk()

# Function to start audio communication
def start_audio_communication():
    receiver = AudioReceiver(socket.gethostbyname(socket.gethostname()), 9999)  # Use the desired port
    sender = AudioSender("CLIENT_IP_ADDRESS", 9998)  # Replace with the IP address of the client
    receiver.start_server()
    sender.start_stream()

# Start audio communication
#start_audio_communication()
btn = (root,text='Audio',padx=5,pady=5,command=start_audio_communication)
btn.pack()
root.mainloop()

# %%
from vidstream import AudioReceiver, AudioSender
import socket
import threading
import keyboard  # You may need to install the "keyboard" library

# Function to start audio communication
def start_audio_communication():
    receiver = AudioReceiver(socket.gethostbyname(socket.gethostname()), 9998)  # Use the desired port
    sender = AudioSender("192.168.29.118", 9989)  # Replace with the IP address of the server
    receiver.start_server()
    sender.start_stream()

    # Listen for the 'q' key to exit
    print("Press 'q' to quit.")
    keyboard.add_hotkey('q', lambda: keyboard.press_and_release('ctrl+break'))  # Terminate with 'ctrl+break'

# Start audio communication
start_audio_communication()

# %%
# !pip install keyboard

# %%
from vidstream import AudioReceiver, AudioSender
import socket
import threading
import keyboard  # You may need to install the "keyboard" library

# Function to start audio communication
def start_audio_communication():
    receiver = AudioReceiver(socket.gethostbyname(socket.gethostname()), 9988)  # Use the desired port
    sender = AudioSender("192.168.29.118", 9889)  # Replace with the IP address of the server
    receiver.start_server()
    sender.start_stream()

    # Listen for the 'q' key to exit
    print("Press 'q' to quit.")
    keyboard.add_hotkey('q', lambda: keyboard.press_and_release('ctrl+break'))  # Terminate with 'ctrl+break'

# Start audio communication
start_audio_communication()

# %%
import tkinter as tk
from PIL import Image, ImageTk
from vidstream import CameraClient
from vidstream import ScreenShareClient
from vidstream import AudioSender
from vidstream import StreamingServer
from vidstream import AudioReceiver
from vidstream import *
import socket
import threading
import requests

local_ip_address = socket.gethostbyname(socket.gethostname())
#print(local_ip_address)
server = StreamingServer(local_ip_address, 41100)
reciever = AudioReceiver(local_ip_address, 32300)

def start_listening():
    t1 = threading.Thread(target=server.start_server).start()
    t2 = threading.Thread(target=reciever.start_server).start()
    
    
def start_camera_stream():
    target_ip = target_ip_entry.get()
    camera_client = CameraClient(target_ip, 7777)
    t3 = threading.Thread(target=camera_client.start_stream).start()

def start_screen_sharing():
    target_ip = target_ip_entry.get()
    screen_client = ScreenShareClient(target_ip, 7777)
    t4 = threading.Thread(target=screen_client.start_stream).start()
    
def start_audio_stream():
    target_ip = target_ip_entry.get()
    audio_sender = AudioSender(target_ip, 6666)
    t5 = threading.Thread(target=audio_sender.start_stream).start()



# Main window
root = tk.Tk()
root.title("Zoom Clone")

# Icon
#icon_image = Image.open("zoom.png")
#icon_photo = ImageTk.PhotoImage(icon_image)
#root.iconphoto(True, icon_photo)

# Icon
iconpath = r"C:\Users\KIIT\Desktop\5th sem materials\Project\zoom.ico"
root.iconbitmap(iconpath)

# Entry for Target IP
target_ip_label = tk.Label(root, text="Enter Target IP:")
target_ip_label.grid(row=0, column=0, padx=5, pady=5)
target_ip_entry = tk.Entry(root)
target_ip_entry.grid(row=0, column=1, padx=5, pady=5)

# Create a 2x2 grid for image buttons
button_width = 70
button_height = 70

listening_image = Image.open("play.png")
listening_image = listening_image.resize((button_width, button_height))
listening_photo = ImageTk.PhotoImage(listening_image)

camera_image = Image.open("camera.png")
camera_image = camera_image.resize((button_width, button_height))
camera_photo = ImageTk.PhotoImage(camera_image)

screen_share_image = Image.open("screen.png")
screen_share_image = screen_share_image.resize((button_width, button_height))
screen_share_photo = ImageTk.PhotoImage(screen_share_image)

audio_stream_image = Image.open("mic.png")
audio_stream_image = audio_stream_image.resize((button_width, button_height))
audio_stream_photo = ImageTk.PhotoImage(audio_stream_image)

listening_button = tk.Button(root, image=listening_photo, command=start_listening, width=button_width, height=button_height, compound=tk.TOP)
camera_stream_button = tk.Button(root, image=camera_photo, command=start_camera_stream, width=button_width, height=button_height, compound=tk.TOP)
screen_share_button = tk.Button(root, image=screen_share_photo, command=start_screen_sharing, width=button_width, height=button_height, compound=tk.TOP)
audio_stream_button = tk.Button(root, image=audio_stream_photo, command=start_audio_stream, width=button_width, height=button_height, compound=tk.TOP)

listening_button.grid(row=1, column=0, padx=5, pady=5)
camera_stream_button.grid(row=1, column=1, padx=5, pady=5)
screen_share_button.grid(row=2, column=0, padx=5, pady=5)
audio_stream_button.grid(row=2, column=1, padx=5, pady=5)

root.mainloop()

# %%
import tkinter as tk
from PIL import Image, ImageTk
from vidstream import CameraClient
from vidstream import ScreenShareClient
from vidstream import AudioSender
from vidstream import StreamingServer
from vidstream import AudioReceiver
from vidstream import *
import socket
import threading
import requests
local_ip_address = socket.gethostbyname(socket.gethostname())

server = StreamingServer(local_ip_address, 9779)
reciever = AudioReceiver(local_ip_address, 8798)

def start_listening():
    t1 = threading.Thread(target=server.start_server)
    t2 = threading.Thread(target=reciever.start_server)
    t1.start()
    t2.start()

def start_camera_stream():
    target_ip = target_ip_entry.get()
    camera_client = CameraClient(target_ip, 7777)
    t3 = threading.Thread(target=camera_client.start_stream)
    t3.start()

def start_screen_sharing():
    target_ip = target_ip_entry.get()
    screen_client = ScreenShareClient(target_ip, 7777)
    t4 = threading.Thread(target=screen_client.start_stream)
    t4.start()

def start_audio_stream():
    target_ip = target_ip_entry.get()
    audio_sender = AudioSender(target_ip, 6666)
    t5 = threading.Thread(target=audio_sender.start_stream)
    t5.start()

root = tk.Tk()
root.title("Zoom Clone")

# Icon
#icon_image = Image.open("zoom.png")
#icon_photo = ImageTk.PhotoImage(icon_image)
#root.iconphoto(True, icon_photo)

# Icon
iconpath = r"C:\Users\KIIT\Desktop\5th sem materials\Project\zoom.ico"
root.iconbitmap(iconpath)

# Entry for Target IP
target_ip_label = tk.Label(root, text="Enter Target IP:")
target_ip_label.grid(row=0, column=0, padx=5, pady=5)
target_ip_entry = tk.Entry(root)
target_ip_entry.grid(row=0, column=1, padx=5, pady=5)

# Create a 2x2 grid for image buttons
button_width = 70
button_height = 70

listening_image = Image.open("play.png")
listening_image = listening_image.resize((button_width, button_height))
listening_photo = ImageTk.PhotoImage(listening_image)

camera_image = Image.open("camera.png")
camera_image = camera_image.resize((button_width, button_height))
camera_photo = ImageTk.PhotoImage(camera_image)

screen_share_image = Image.open("screen.png")
screen_share_image = screen_share_image.resize((button_width, button_height))
screen_share_photo = ImageTk.PhotoImage(screen_share_image)

audio_stream_image = Image.open("mic.png")
audio_stream_image = audio_stream_image.resize((button_width, button_height))
audio_stream_photo = ImageTk.PhotoImage(audio_stream_image)

listening_button = tk.Button(root, image=listening_photo, command=start_listening, width=button_width, height=button_height, compound=tk.TOP)
camera_stream_button = tk.Button(root, image=camera_photo, command=start_camera_stream, width=button_width, height=button_height, compound=tk.TOP)
screen_share_button = tk.Button(root, image=screen_share_photo, command=start_screen_sharing, width=button_width, height=button_height, compound=tk.TOP)
audio_stream_button = tk.Button(root, image=audio_stream_photo, command=start_audio_stream, width=button_width, height=button_height, compound=tk.TOP)

listening_button.grid(row=1, column=0, padx=5, pady=5)
camera_stream_button.grid(row=1, column=1, padx=5, pady=5)
screen_share_button.grid(row=2, column=0, padx=5, pady=5)
audio_stream_button.grid(row=2, column=1, padx=5, pady=5)

root.mainloop()

# %%
from vidstream import AudioReceiver, AudioSender
import socket
import threading
import socket
from tkinter import *
root = Tk()
# Function to start audio communication
def start_audio_communication():
    receiver = AudioReceiver(socket.gethostbyname(socket.gethostname()), 9998)  # Use the desired port
    sender = AudioSender("192.168.29.118", 9899)  # Replace with the IP address of the server
    receiver.start_server()
    sender.start_stream()

# Start audio communication
#start_audio_communication()
btn = Button(root,text="Audio",padx=5,pady=5,command=start_audio_communication)
btn.pack()
root.mainloop()

# %%
import tkinter as tk
from PIL import Image, ImageTk
from vidstream import CameraClient
from vidstream import ScreenShareClient
from vidstream import AudioSender
from vidstream import StreamingServer
from vidstream import AudioReceiver
from vidstream import *
import socket
import threading
import requests
local_ip_address = socket.gethostbyname(socket.gethostname())

server = StreamingServer(local_ip_address, 9999)
reciever = AudioReceiver(local_ip_address, 8888)

def start_listening():
    t1 = threading.Thread(target=server.start_server)
    t2 = threading.Thread(target=reciever.start_server)
    t1.start()
    t2.start()

def start_camera_stream():
    target_ip = target_ip_entry.get()
    camera_client = CameraClient(target_ip, 7777)
    t3 = threading.Thread(target=camera_client.start_stream)
    t3.start()

def start_screen_sharing():
    target_ip = target_ip_entry.get()
    screen_client = ScreenShareClient(target_ip, 7777)
    t4 = threading.Thread(target=screen_client.start_stream)
    t4.start()

def start_audio_stream():
    target_ip = target_ip_entry.get()

    # Set the timeout value on the sending socket
    audio_sender = AudioSender(target_ip, 6666, timeout=10)

    t5 = threading.Thread(target=audio_sender.start_stream)
    t5.start()
    
root = tk.Tk()
root.title("Zoom Clone")

# Icon
#icon_image = Image.open("zoom.png")
#icon_photo = ImageTk.PhotoImage(icon_image)
#root.iconphoto(True, icon_photo)

# Icon
iconpath = r"C:\Users\KIIT\Desktop\5th sem materials\Project\zoom.ico"
root.iconbitmap(iconpath)

# Entry for Target IP
target_ip_label = tk.Label(root, text="Enter Target IP:")
target_ip_label.grid(row=0, column=0, padx=5, pady=5)
target_ip_entry = tk.Entry(root)
target_ip_entry.grid(row=0, column=1, padx=5, pady=5)

# Create a 2x2 grid for image buttons
button_width = 70
button_height = 70

listening_image = Image.open("play.png")
listening_image = listening_image.resize((button_width, button_height))
listening_photo = ImageTk.PhotoImage(listening_image)

camera_image = Image.open("camera.png")
camera_image = camera_image.resize((button_width, button_height))
camera_photo = ImageTk.PhotoImage(camera_image)

screen_share_image = Image.open("screen.png")
screen_share_image = screen_share_image.resize((button_width, button_height))
screen_share_photo = ImageTk.PhotoImage(screen_share_image)

audio_stream_image = Image.open("mic.png")
audio_stream_image = audio_stream_image.resize((button_width, button_height))
audio_stream_photo = ImageTk.PhotoImage(audio_stream_image)

listening_button = tk.Button(root, image=listening_photo, command=start_listening, width=button_width, height=button_height, compound=tk.TOP)
camera_stream_button = tk.Button(root, image=camera_photo, command=start_camera_stream, width=button_width, height=button_height, compound=tk.TOP)
screen_share_button = tk.Button(root, image=screen_share_photo, command=start_screen_sharing, width=button_width, height=button_height, compound=tk.TOP)
audio_stream_button = tk.Button(root, image=audio_stream_photo, command=start_audio_stream, width=button_width, height=button_height, compound=tk.TOP)

listening_button.grid(row=1, column=0, padx=5, pady=5)
camera_stream_button.grid(row=1, column=1, padx=5, pady=5)
screen_share_button.grid(row=2, column=0, padx=5, pady=5)
audio_stream_button.grid(row=2, column=1, padx=5, pady=5)

root.mainloop()

# %%
import tkinter as tk
from PIL import Image, ImageTk
from vidstream import CameraClient
from vidstream import ScreenShareClient
from vidstream import AudioSender
from vidstream import StreamingServer
from vidstream import AudioReceiver
from vidstream import *
import socket
import threading
import requests
local_ip_address = socket.gethostbyname(socket.gethostname())

server = StreamingServer(local_ip_address, 9999)
receiver = AudioReceiver(local_ip_address, 8889)

def start_listening():
    t1 = threading.Thread(target=server.start_server)
    t2 = threading.Thread(target=receiver.start_server)
    t1.start()
    t2.start()

def start_camera_stream():
    target_ip = target_ip_entry.get()
    camera_client = CameraClient(target_ip, 7777)
    t3 = threading.Thread(target=camera_client.start_stream)
    t3.start()

def start_screen_sharing():
    target_ip = target_ip_entry.get()
    screen_client = ScreenShareClient(target_ip, 7777)
    t4 = threading.Thread(target=screen_client.start_stream)
    t4.start()

def start_audio_stream():
    target_ip = target_ip_entry.get()
    audio_sender = AudioSender(target_ip, 6666)
    t5 = threading.Thread(target=audio_sender.start_stream)
    t5.start()
    
root = tk.Tk()
root.title("Zoom Clone")

# Icon
#icon_image = Image.open("zoom.png")
#icon_photo = ImageTk.PhotoImage(icon_image)
#root.iconphoto(True, icon_photo)

# Icon
iconpath = r"C:\Users\KIIT\Desktop\5th sem materials\Project\zoom.ico"
root.iconbitmap(iconpath)

# Entry for Target IP
target_ip_label = tk.Label(root, text="Enter Target IP:")
target_ip_label.grid(row=0, column=0, padx=5, pady=5)
target_ip_entry = tk.Entry(root)
target_ip_entry.grid(row=0, column=1, padx=5, pady=5)

# Create a 2x2 grid for image buttons
button_width = 70
button_height = 70

listening_image = Image.open("play.png")
listening_image = listening_image.resize((button_width, button_height))
listening_photo = ImageTk.PhotoImage(listening_image)

camera_image = Image.open("camera.png")
camera_image = camera_image.resize((button_width, button_height))
camera_photo = ImageTk.PhotoImage(camera_image)

screen_share_image = Image.open("screen.png")
screen_share_image = screen_share_image.resize((button_width, button_height))
screen_share_photo = ImageTk.PhotoImage(screen_share_image)

audio_stream_image = Image.open("mic.png")
audio_stream_image = audio_stream_image.resize((button_width, button_height))
audio_stream_photo = ImageTk.PhotoImage(audio_stream_image)

listening_button = tk.Button(root, image=listening_photo, command=start_listening, width=button_width, height=button_height, compound=tk.TOP)
camera_stream_button = tk.Button(root, image=camera_photo, command=start_camera_stream, width=button_width, height=button_height, compound=tk.TOP)
screen_share_button = tk.Button(root, image=screen_share_photo, command=start_screen_sharing, width=button_width, height=button_height, compound=tk.TOP)
audio_stream_button = tk.Button(root, image=audio_stream_photo, command=start_audio_stream, width=button_width, height=button_height, compound=tk.TOP)

listening_button.grid(row=1,column=0, padx=5, pady=5)
camera_stream_button.grid(row=1, column=1, padx=5, pady=5)
screen_share_button.grid(row=2, column=0, padx=5, pady=5)
audio_stream_button.grid(row=2, column=1, padx=5, pady=5)

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 14
#      11 import requests
#      12 local_ip_address = socket.gethostbyname(socket.gethostname())
# ---> 14 server = StreamingServer(local_ip_address, 9999)
#      15 receiver = AudioReceiver(local_ip_address, 8889)
#      17 def start_listening():
#
# File ~\AppData\Roaming\Python\Python310\site-packages\vidstream\streaming.py:89, in StreamingServer.__init__(self, host, port, slots, quit_key)
#      87 self.__block = threading.Lock()
#      88 self.__server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
# ---> 89 self.__init_socket()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\vidstream\streaming.py:95, in StreamingServer.__init_socket(self)
#      91 def __init_socket(self):
#      92     """
#      93     Binds the server socket to the given host and port
#      94     """
# ---> 95     self.__server_socket.bind((self.__host, self.__port))
#
# OSError: [WinError 10048] Only one usage of each socket address (protocol/network address/port) is normally permitted

# %%
import tkinter as tk
from PIL import Image, ImageTk
from vidstream import CameraClient, ScreenShareClient, AudioSender, StreamingServer, AudioReceiver
import socket
import threading

local_ip_address = socket.gethostbyname(socket.gethostname())
camera_port = 7777
screen_share_port = 7778
audio_stream_port = 6666
listening_port = 9999
audio_receive_port = 8888

server = StreamingServer(local_ip_address, listening_port)
receiver = AudioReceiver(local_ip_address, audio_receive_port)

def start_listening():
    t1 = threading.Thread(target=server.start_server)
    t2 = threading.Thread(target=receiver.start_server)
    t1.start()
    t2.start()

def start_camera_stream():
    target_ip = target_ip_entry.get()
    camera_client = CameraClient(target_ip, camera_port)
    t3 = threading.Thread(target=camera_client.start_stream)
    t3.start()

def start_screen_sharing():
    target_ip = target_ip_entry.get()
    screen_client = ScreenShareClient(target_ip, screen_share_port)
    t4 = threading.Thread(target=screen_client.start_stream)
    t4.start()

def start_audio_stream():
    target_ip = target_ip_entry.get()
    audio_sender = AudioSender(target_ip, audio_stream_port, timeout=10)
    t5 = threading.Thread(target=audio_sender.start_stream)
    t5.start()

root = tk.Tk()
root.title("Zoom Clone")

# Icon
iconpath = r"C:\Users\KIIT\Desktop\5th sem materials\Project\zoom.ico"
root.iconbitmap(iconpath)

# Entry for Target IP
target_ip_label = tk.Label(root, text="Enter Target IP:")
target_ip_label.grid(row=0, column=0, padx=5, pady=5)
target_ip_entry = tk.Entry(root)
target_ip_entry.grid(row=0, column=1, padx=5, pady=5)

# Create a 2x2 grid for image buttons
button_width = 70
button_height = 70

# ... Rest of your code for buttons ...
listening_image = Image.open("play.png")
listening_image = listening_image.resize((button_width, button_height))
listening_photo = ImageTk.PhotoImage(listening_image)

camera_image = Image.open("camera.png")
camera_image = camera_image.resize((button_width, button_height))
camera_photo = ImageTk.PhotoImage(camera_image)

screen_share_image = Image.open("screen.png")
screen_share_image = screen_share_image.resize((button_width, button_height))
screen_share_photo = ImageTk.PhotoImage(screen_share_image)

audio_stream_image = Image.open("mic.png")
audio_stream_image = audio_stream_image.resize((button_width, button_height))
audio_stream_photo = ImageTk.PhotoImage(audio_stream_image)

listening_button = tk.Button(root, image=listening_photo, command=start_listening, width=button_width, height=button_height, compound=tk.TOP)
camera_stream_button = tk.Button(root, image=camera_photo, command=start_camera_stream, width=button_width, height=button_height, compound=tk.TOP)
screen_share_button = tk.Button(root, image=screen_share_photo, command=start_screen_sharing, width=button_width, height=button_height, compound=tk.TOP)
audio_stream_button = tk.Button(root, image=audio_stream_photo, command=start_audio_stream, width=button_width, height=button_height, compound=tk.TOP)

listening_button.grid(row=1,column=0, padx=5, pady=5)
camera_stream_button.grid(row=1, column=1, padx=5, pady=5)
screen_share_button.grid(row=2, column=0, padx=5, pady=5)
audio_stream_button.grid(row=2, column=1, padx=5, pady=5)


root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 14
#      11 listening_port = 9999
#      12 audio_receive_port = 8888
# ---> 14 server = StreamingServer(local_ip_address, listening_port)
#      15 receiver = AudioReceiver(local_ip_address, audio_receive_port)
#      17 def start_listening():
#
# File ~\AppData\Roaming\Python\Python310\site-packages\vidstream\streaming.py:89, in StreamingServer.__init__(self, host, port, slots, quit_key)
#      87 self.__block = threading.Lock()
#      88 self.__server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
# ---> 89 self.__init_socket()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\vidstream\streaming.py:95, in StreamingServer.__init_socket(self)
#      91 def __init_socket(self):
#      92     """
#      93     Binds the server socket to the given host and port
#      94     """
# ---> 95     self.__server_socket.bind((self.__host, self.__port))
#
# OSError: [WinError 10048] Only one usage of each socket address (protocol/network address/port) is normally permitted

# %%
import tkinter as tk
from PIL import Image, ImageTk
from vidstream import *
import socket
import threading
import requests

local_ip_address = socket.gethostbyname(socket.gethostname())
#print(local_ip_address)
server = StreamingServer(local_ip_address, 9893)
reciever = AudioReceiver(local_ip_address, 8983)

def start_listening():
    t1 = threading.Thread(target=server.start_server)
    t2 = threading.Thread(target=reciever.start_server)
    t1.start()
    t2.start()
    
    
def start_camera_stream():
    target_ip = target_ip_entry.get()
    camera_client = CameraClient(target_ip, 7773)
    t3 = threading.Thread(target=camera_client.start_stream)
    t3.start()

def start_screen_sharing():
    target_ip = target_ip_entry.get()
    screen_client = ScreenShareClient(target_ip, 7773)
    t4 = threading.Thread(target=screen_client.start_stream)
    t4.start()
    
def start_audio_stream():
    target_ip = target_ip_entry.get()
    audio_sender = AudioSender(target_ip, 6663)
    t5 = threading.Thread(target=audio_sender.start_stream)
    t5.start()

def exit_application():
    root.quit()

# Main window
root = tk.Tk()
root.title("Zoom Clone")

# Icon
#icon_image = Image.open("zoom.png")
#icon_photo = ImageTk.PhotoImage(icon_image)
#root.iconphoto(True, icon_photo)

# Icon
iconpath = r"C:\Users\KIIT\Desktop\5th sem materials\Project\zoom.ico"
root.iconbitmap(iconpath)

# Entry for Target IP
target_ip_label = tk.Label(root, text="Enter Target IP:")
target_ip_label.grid(row=0, column=0, padx=5, pady=5)
target_ip_entry = tk.Entry(root)
target_ip_entry.grid(row=0, column=1, padx=5, pady=5)

# Create a 2x2 grid for image buttons
button_width = 70
button_height = 70

listening_image = Image.open("play.png")
listening_image = listening_image.resize((button_width, button_height))
listening_photo = ImageTk.PhotoImage(listening_image)

camera_image = Image.open("camera.png")
camera_image = camera_image.resize((button_width, button_height))
camera_photo = ImageTk.PhotoImage(camera_image)

screen_share_image = Image.open("screen.png")
screen_share_image = screen_share_image.resize((button_width, button_height))
screen_share_photo = ImageTk.PhotoImage(screen_share_image)

audio_stream_image = Image.open("mic.png")
audio_stream_image = audio_stream_image.resize((button_width, button_height))
audio_stream_photo = ImageTk.PhotoImage(audio_stream_image)

listening_button = tk.Button(root, image=listening_photo, command=start_listening, width=button_width, height=button_height, compound=tk.TOP)
camera_stream_button = tk.Button(root, image=camera_photo, command=start_camera_stream, width=button_width, height=button_height, compound=tk.TOP)
screen_share_button = tk.Button(root, image=screen_share_photo, command=start_screen_sharing, width=button_width, height=button_height, compound=tk.TOP)
audio_stream_button = tk.Button(root, image=audio_stream_photo, command=start_audio_stream, width=button_width, height=button_height, compound=tk.TOP)

listening_button.grid(row=1, column=0, padx=5, pady=5)
camera_stream_button.grid(row=1, column=1, padx=5, pady=5)
screen_share_button.grid(row=2, column=0, padx=5, pady=5)
audio_stream_button.grid(row=2, column=1, padx=5, pady=5)


exit_button = tk.Button(root, text="Exit", command=exit_application)
exit_button.grid(row=3, column=0, columnspan=2, padx=5, pady=10)

root.mainloop()

# %%
import tkinter as tk
from PIL import Image, ImageTk
from vidstream import *
import socket
import threading
import requests

local_ip_address = socket.gethostbyname(socket.gethostname())
#print(local_ip_address)
server = StreamingServer(local_ip_address, 9873)
reciever = AudioReceiver(local_ip_address, 8973)

def start_listening():
    t1 = threading.Thread(target=server.start_server)
    t2 = threading.Thread(target=reciever.start_server)
    t1.start()
    t2.start()
    
    
def start_camera_stream():
    target_ip = target_ip_entry.get()
    camera_client = CameraClient(target_ip, 5555)
    t3 = threading.Thread(target=camera_client.start_stream)
    t3.start()

def start_screen_sharing():
    target_ip = target_ip_entry.get()
    screen_client = ScreenShareClient(target_ip, 5555)
    t4 = threading.Thread(target=screen_client.start_stream)
    t4.start()
    
def start_audio_stream():
    target_ip = target_ip_entry.get()
    audio_sender = AudioSender(target_ip, 5554)
    t5 = threading.Thread(target=audio_sender.start_stream)
    t5.start()

def exit_application():
    root.destroy()

# Main window
root = tk.Tk()
root.title("Zoom Clone")

# Icon
#icon_image = Image.open("zoom.png")
#icon_photo = ImageTk.PhotoImage(icon_image)
#root.iconphoto(True, icon_photo)

# Icon
iconpath = r"C:\Users\KIIT\Desktop\5th sem materials\Project\zoom.ico"
root.iconbitmap(iconpath)

# Entry for Target IP
target_ip_label = tk.Label(root, text="Enter Target IP:")
target_ip_label.grid(row=0, column=0, padx=5, pady=5)
target_ip_entry = tk.Entry(root)
target_ip_entry.grid(row=0, column=1, padx=5, pady=5)

# Create a 2x2 grid for image buttons
button_width = 70
button_height = 70

listening_image = Image.open("play.png")
listening_image = listening_image.resize((button_width, button_height))
listening_photo = ImageTk.PhotoImage(listening_image)

camera_image = Image.open("camera.png")
camera_image = camera_image.resize((button_width, button_height))
camera_photo = ImageTk.PhotoImage(camera_image)

screen_share_image = Image.open("screen.png")
screen_share_image = screen_share_image.resize((button_width, button_height))
screen_share_photo = ImageTk.PhotoImage(screen_share_image)

audio_stream_image = Image.open("mic.png")
audio_stream_image = audio_stream_image.resize((button_width, button_height))
audio_stream_photo = ImageTk.PhotoImage(audio_stream_image)

listening_button = tk.Button(root, image=listening_photo, command=start_listening, width=button_width, height=button_height, compound=tk.TOP)
camera_stream_button = tk.Button(root, image=camera_photo, command=start_camera_stream, width=button_width, height=button_height, compound=tk.TOP)
screen_share_button = tk.Button(root, image=screen_share_photo, command=start_screen_sharing, width=button_width, height=button_height, compound=tk.TOP)
audio_stream_button = tk.Button(root, image=audio_stream_photo, command=start_audio_stream, width=button_width, height=button_height, compound=tk.TOP)

listening_button.grid(row=1, column=0, padx=5, pady=5)
camera_stream_button.grid(row=1, column=1, padx=5, pady=5)
screen_share_button.grid(row=2, column=0, padx=5, pady=5)
audio_stream_button.grid(row=2, column=1, padx=5, pady=5)


exit_button = tk.Button(root, text="Exit", command=exit_application)
exit_button.grid(row=3, column=0, columnspan=2, padx=5, pady=10)

root.mainloop()
# Out:
# Server is already running
# Audio server is running already
