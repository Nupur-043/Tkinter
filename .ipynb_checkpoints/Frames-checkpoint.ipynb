# %%
from tkinter import *
from PIL import ImageTk, Image

# %%
root = Tk()
root.title('Adding Frames to program')
iconpath=r"C:\Users\KIIT\Desktop\5th sem materials\Project\python_squre_icon_icon_257067.ico"
root.iconbitmap(iconpath)
#frames keeps things organize in an app there are different sections
#that we put together visually 

frame = LabelFrame(root, text='This is my Frame...', padx=5, pady=5)
frame.pack(padx=10, pady=10)

b = Button(frame, text='Dont click me')
b.pack()

root.mainloop()

# %% [markdown]
# we cannot use both pack and grid earlier but in frame inside pack we can do grid inside frame.
# pack is used when we don't care where the widget is placed but grid is used when we have to place it in a specific position.
# pack is used with pack grid is used with grid earlier.

# %%
root = Tk()
root.title('Radio buttons')
iconpath=r"C:\Users\KIIT\Desktop\5th sem materials\Project\python_squre_icon_icon_257067.ico"
root.iconbitmap(iconpath)
# allows tkinter to keep track of changes overtime of variable
#so when we click on a thing it'll know that 
r=IntVar()
r.set('2')
#r.get() gets whereever the variable is at the moment 

def clicked(value):
    myLabel = Label(root, text=r.get())
    myLabel.pack()

    


Radiobutton(root, text='Option 1', variable=r, value=1, command=lambda: clicked(r.get())).pack()
Radiobutton(root, text='Option 2', variable=r, value=2,command=lambda: clicked(r.get())).pack()
#tkinter variables are different from python 
#they need to be integer variables 

myLabel = Label(root, text=r.get())
myLabel.pack()

myButton = Button(root, text='Click Me!', command=lambda: clicked(r.get()))
myButton.pack()

root.mainloop()

# %%
root = Tk()
root.title('Radio buttons')
iconpath=r"C:\Users\KIIT\Desktop\5th sem materials\Project\python_squre_icon_icon_257067.ico"
root.iconbitmap(iconpath)
# allows tkinter to keep track of changes overtime of variable
#so when we click on a thing it'll know that 
# r=IntVar()
# r.set('2')
#r.get() gets whereever the variable is at the moment 

MODES= [
    ('Pepperoni','Pepperoni'),
    ('Cheese','Cheese'),
    ('Mushroom','Mushroom'),
    ('Onion','Onion'),
    #text,    #mode
]

pizza = StringVar()
pizza.set('Pepperoni')

for text, mode in MODES:
    Radiobutton(root, text=text, variable=pizza,value=mode).pack(anchor=W)

def clicked(value):
    myLabel = Label(root, text=value)
    myLabel.pack()

    


#Radiobutton(root, text='Option 1', variable=r, value=1, command=lambda: clicked(r.get())).pack()
#Radiobutton(root, text='Option 2', variable=r, value=2,command=lambda: clicked(r.get())).pack()
#tkinter variables are different from python 
#they need to be integer variables 

#myLabel = Label(root, text=pizza.get())
#myLabel.pack()

myButton = Button(root, text='Click Me!', command=lambda: clicked(pizza.get()))
myButton.pack()

root.mainloop()

# %% [markdown]
# ### Message box

# %%
from tkinter import messagebox
root = Tk()
root.title('Messasge boxes')

iconpath=r"C:\Users\KIIT\Desktop\5th sem materials\Project\python_squre_icon_icon_257067.ico"
root.iconbitmap(iconpath)

def popup():
    messagebox.showinfo('This is my popup!','Hello world!')


Button(root, text='popup', command=popup).pack()

root.mainloop()

# %%
root = Tk()
def popup():
    #showinfo, showwarning, showerror, askquestion, askokcancel,askyesno
    messagebox.showinfo('Hi thi si my practice popup','do u need help')
Button(root,text='popup',command=popup).pack()
root.mainloop()

# %%
root = Tk()
def popup():
    #showinfo, showwarning, showerror, askquestion, askokcancel,askyesno
    response = messagebox.askyesno('Hi thi si my practice popup','do u need help')
    #Label(root, text=response).pack()
    if response == 1:
        Label(root, text='You clicked yes').pack()
    else:
        Label(root, text='You clicked no').pack()
Button(root,text='popup',command=popup).pack()
root.mainloop()

# %% [markdown]
# ### Create Windows

# %%
root = Tk()
root.title('My window')


iconpath=r"C:\Users\KIIT\Desktop\5th sem materials\Project\python_squre_icon_icon_257067.ico"
root.iconbitmap(iconpath)


top = Toplevel()
lbl = Label(top, text='hello world' ).pack()


root.mainloop()

# %%
root = Tk()
root.title('My window')


iconpath=r"C:\Users\KIIT\Desktop\5th sem materials\Project\python_squre_icon_icon_257067.ico"
root.iconbitmap(iconpath)

def open():
    top = Toplevel()
    top.title('My 2nd window')
    global img #else pic won't be displaued the local var is dumpedin garbage

    iconpath=r"C:\Users\KIIT\Desktop\5th sem materials\Project\python_squre_icon_icon_257067.ico"
    top.iconbitmap(iconpath)
    img = ImageTk.PhotoImage(Image.open('images/dog.png'))
    my_label = Label(top,image=img).pack()
    btn2 = Button(top, text='close window', command=top.destroy).pack()
#top.destroy is how u close things

btn = Button(root, text='Open Seond Window', command=open).pack()




root.mainloop()

# %% [markdown]
# ### Open Files Dialog Box

# %%
from tkinter import filedialog
root = Tk()
root.title('File Dialog Box')

iconpath=r"\Users\KIIT\Desktop\5th sem materials\Project\python_squre_icon_icon_257067.ico"
root.iconbitmap(iconpath)

root.filename =  filedialog.askopenfilename(initialdir=r'C:\Users\KIIT\Desktop\5th sem materials\Project\images',title='select a file',filetypes=(('png files','*.png'),('all file','*.*')))

root.mainloop()

# %%
from tkinter import filedialog
root = Tk()
root.title('File Dialog Box')

iconpath=r"\Users\KIIT\Desktop\5th sem materials\Project\python_squre_icon_icon_257067.ico"
root.iconbitmap(iconpath)

root.filename =  filedialog.askopenfilename(initialdir=r'C:\Users\KIIT\Desktop\5th sem materials\Project\images',title='select a file',filetypes=(('jpg files','*.jpg'),('all file','*.*')))
# my_label = Label(root, text=root.filename).pack()
#this will show the location of the file 


root.mainloop()

# %%
from tkinter import filedialog
root = Tk()
root.title('File Dialog Box')

iconpath=r"\Users\KIIT\Desktop\5th sem materials\Project\python_squre_icon_icon_257067.ico"
root.iconbitmap(iconpath)

root.filename =  filedialog.askopenfilename(initialdir=r'C:\Users\KIIT\Desktop\5th sem materials\Project\images',title='select a file',filetypes=(('jpg files','*.jpg'),('all file','*.*')))
# my_label = Label(root, text=root.filename).pack()
#this will show the location of the file 

img = ImageTk.PhotoImage(Image.open(root.filename))
imglbl = Label(image=img).pack()
root.mainloop()

# %%
from tkinter import filedialog
root = Tk()
root.title('File Dialog Box')

iconpath=r"\Users\KIIT\Desktop\5th sem materials\Project\python_squre_icon_icon_257067.ico"
root.iconbitmap(iconpath)

#root.filename =  filedialog.askopenfilename(initialdir=r'C:\Users\KIIT\Desktop\5th sem materials\Project\images',title='select a file',filetypes=(('jpg files','*.jpg'),('all file','*.*')))
# my_label = Label(root, text=root.filename).pack()
#this will show the location of the file 

#img = ImageTk.PhotoImage(Image.open(root.filename))
#imglbl = Label(image=img).pack()

def open():
    global img
    
    root.filename =  filedialog.askopenfilename(initialdir=r'C:\Users\KIIT\Desktop\5th sem materials\Project\images',title='select a file',filetypes=(('jpg files','*.jpg'),('all file','*.*')))
    my_label = Label(root, text=root.filename).pack()
    img = ImageTk.PhotoImage(Image.open(root.filename))
    imglbl = Label(image=img).pack()

my_btn = Button(root, text='Open File', command=open).pack()

root.mainloop()

# %% [markdown]
# ### sliders

# %%
root = Tk()
root.title('sliders')

iconpath=r"\Users\KIIT\Desktop\5th sem materials\Project\python_squre_icon_icon_257067.ico"
root.iconbitmap(iconpath)
root.geometry("400x400")

#pack is written in different line
vertical = Scale(root, from_=0, to=200)
vertical.pack()

horizontal = Scale(root, from_=0, to=200, orient=HORIZONTAL)
horizontal.pack()

lbl= Label(root, text=horizontal.get()).pack()

def slide():
    lbl= Label(root, text=horizontal.get()).pack()
    root.geometry(str(horizontal.get())+ "x400")
    

my_btn = Button(root, text='Click Me!', command=slide).pack()



root.mainloop()

# %%
root = Tk()
root.title('sliders')

iconpath=r"\Users\KIIT\Desktop\5th sem materials\Project\python_squre_icon_icon_257067.ico"
root.iconbitmap(iconpath)
root.geometry("400x400")

#pack is written in different line
vertical = Scale(root, from_=0, to=200)
vertical.pack()
 #slide func is not picking up with .get() thing 
def slide(var):
    lbl= Label(root, text=horizontal.get()).pack()
    root.geometry(str(horizontal.get())+ "x400")

horizontal = Scale(root, from_=0, to=200, orient=HORIZONTAL,command=slide)
horizontal.pack()

lbl= Label(root, text=horizontal.get()).pack()


    

my_btn = Button(root, text='Click Me!', command=slide).pack()



root.mainloop()

# %%
root = Tk()
root.title('sliders')

iconpath=r"\Users\KIIT\Desktop\5th sem materials\Project\python_squre_icon_icon_257067.ico"
root.iconbitmap(iconpath)
root.geometry("400x400")

#pack is written in different line
vertical = Scale(root, from_=0, to=200)
vertical.pack()
 #slide func is not picking up with .get() thing 
def slide():
    lbl= Label(root, text=horizontal.get()).pack()
    root.geometry(str(horizontal.get())+"x"+str(vertical.get()) )

horizontal = Scale(root, from_=0, to=200, orient=HORIZONTAL)
horizontal.pack()

lbl= Label(root, text=horizontal.get()).pack()


    

my_btn = Button(root, text='Click Me!', command=slide).pack()



root.mainloop()

# %% [markdown]
# #### Checkboxes

# %%
root = Tk()
root.title('sliders')

iconpath = r"\Users\KIIT\Desktop\5th sem materials\Project\python_squre_icon_icon_257067.ico"
root.iconbitmap(iconpath)
root.geometry("400x400")

def show():
    myLabel = Label(root,text=var.get()).pack()


var = IntVar()
#values are either 0 or 1 - 1 means we have checked it 


c=Checkbutton(root,text='check this vox.',variable=var)
c.pack()

myLabel = Label(root,text=var.get()).pack()
mybtn = Button(root, text = 'show selection',command=show).pack()


root.mainloop()

# %%
root = Tk()
root.title('sliders')

iconpath = r"\Users\KIIT\Desktop\5th sem materials\Project\python_squre_icon_icon_257067.ico"
root.iconbitmap(iconpath)
root.geometry("400x400")

def show():
    myLabel = Label(root,text=var.get()).pack()


var = StringVar()
#values are either 0 or 1 - 1 means we have checked it 


c=Checkbutton(root,text='check this vox.',variable=var,onvalue='On', offvalue='Off')
c.deselect() #deselects by default
c.pack()

myLabel = Label(root,text=var.get()).pack()
mybtn = Button(root, text = 'show selection',command=show).pack()


root.mainloop()

# %%
root = Tk()
root.title('sliders')

iconpath = r"\Users\KIIT\Desktop\5th sem materials\Project\python_squre_icon_icon_257067.ico"
root.iconbitmap(iconpath)
root.geometry("400x400")

def show():
    myLabel = Label(root,text=var.get()).pack()


var = StringVar()
#values are either 0 or 1 - 1 means we have checked it 


c=Checkbutton(root,text='check this vox.',variable=var,onvalue='On', offvalue='Off')
c.deselect() #deselects by default
c.pack()

myLabel = Label(root,text=var.get()).pack()
mybtn = Button(root, text = 'show selection',command=show).pack()


root.mainloop()

# %% [markdown]
# #### Dropdown menus

# %%
root = Tk()
root.title('Dropdown')

iconpath = r"\Users\KIIT\Desktop\5th sem materials\Project\python_squre_icon_icon_257067.ico"
root.iconbitmap(iconpath)
root.geometry("400x400")
 #Drop Down Boxes

def show():
    myLabel = Label(root, text=clicked.get()).pack()

options = [
    "Monday",
    'Tuesday',
    'Thursday',
    'Wednesday',
    'Friday',
    'Saturday'
    
]    
    
clicked = StringVar() 
clicked.set(options[3])
    
drop = OptionMenu(root, clicked,*options )
drop.pack()


myButton = Button(root, text='Show Selection', command=show).pack()



root.mainloop()

# %% [markdown]
# ## Using Databases

# %%
from tkinter import *
from PIL import ImageTk, Image
import sqlite3


#sqlite has only 5 datatypes texts, integers, a real, null and blobs 

root = Tk()
root.title('Using databases')
iconpath = r"\Users\KIIT\Desktop\5th sem materials\Project\python_squre_icon_icon_257067.ico"
root.iconbitmap(iconpath)
root.geometry("400x400")


# Databases


# Create a databasee or connect to one
conn = sqlite3.connect('address_book.db')


# Create a cursor 
c = conn.cursor()

# Create a Table
c.execute("""CREATE TABLE addresses(
first_name text, 
last_name text, 
address text,
city text, 
state text, 
zipcode integer)

""")

# Commit Changes
conn.commit()


# Close connection
conn.close()

root.mainloop()

# %% [markdown]
# ### Building Out the GUI For Our Database App

# %%
from tkinter import *
from PIL import ImageTk, Image
import sqlite3


#sqlite has only 5 datatypes texts, integers, a real, null and blobs 

root = Tk()
root.title('Using databases')
iconpath = r"\Users\KIIT\Desktop\5th sem materials\Project\python_squre_icon_icon_257067.ico"
root.iconbitmap(iconpath)
root.geometry("600x400")


# Databases


# Create a databasee or connect to one
conn = sqlite3.connect('address_book.db')


# Create a cursor 
c = conn.cursor()

# Create a Table
#we commented out the table because we don't need to create the 
#table again and again once it is created 
'''
c.execute("""CREATE TABLE addresses(
first_name text, 
last_name text, 
address text,
city text, 
state text, 
zipcode integer)

""")
'''
# Create submit function for database
def submit():
    # Create a databasee or connect to one
    conn = sqlite3.connect('address_book.db')


    # Create a cursor 
    c = conn.cursor()
    
    #insert into table
    c.execute('INSERT INTO addresses VALUES(:f_name,:l_name,:addre,:city,:state,:zipc  )',
             {
                 'f_name':f_name.get(),
                 'l_name':l_name.get(),
                 'addre':addre.get(),
                 'city':city.get(),
                 'state':state.get(),
                 'zipc':zipc.get()
             })

    # Commit Changes
    conn.commit()


    # Close connection
    conn.close()
    
    
    
    
    
    
    # Clear the text Boxes
    f_name.delete(0, END)
    l_name.delete(0, END)
    addre.delete(0, END)
    city.delete(0, END)
    state.delete(0, END)
    zipc.delete(0, END)

    
    
    
# Create query function
def query():
    # Create a databasee or connect to one
    conn = sqlite3.connect('address_book.db')


    # Create a cursor 
    c = conn.cursor()
    
    # Query the database
    c.execute('SELECT *, oid FROM addresses')
    records = c.fetchall()
 #   print(records)
    #fetchone, fetchmany
    # LOOP thorugh results
    print_records = ''
    for record in records:
        print_records += str(record ) + '\n'
        
    query_label = Label(root, text=print_records)
    query_label.grid(row=8, column=0, columnspan=3)
        
        
        
     # Commit Changes
    conn.commit()


    # Close connection
    conn.close()
    
    return 



# Create text boxes
f_name = Entry(root, width=30)
f_name.grid(row=0,column=1, padx=20)
l_name = Entry(root, width=30)
l_name.grid(row=1,column=1, padx=20)
addre = Entry(root, width=30)
addre.grid(row=2,column=1, padx=20)
city = Entry(root, width=30)
city.grid(row=3,column=1, padx=20)
state = Entry(root, width=30)
state.grid(row=4,column=1, padx=20)
zipc = Entry(root, width=30)
zipc.grid(row=5,column=1, padx=20)

# Create text box label

f_name_lbl = Label(root, text='First Name')
f_name_lbl.grid(row=0, column=0)
l_name_lbl = Label(root, text='Last Name')
l_name_lbl.grid(row=1, column=0)
addre_lbl = Label(root, text='Address')
addre_lbl.grid(row=2, column=0)
city_lbl = Label(root, text='City')
city_lbl.grid(row=3, column=0)
state_lbl = Label(root, text='State')
state_lbl.grid(row=4, column=0)
zipc_lbl = Label(root, text='Zipcode')
zipc_lbl.grid(row=5, column=0)


# Create Submit Button
submit_btn = Button(root, text='Add record to database', command=submit)
submit_btn.grid(row=6, column=0,columnspan=2, pady=10, padx=10, ipadx=100)

# Query  button 
query_btn = Button(root, text='Show records',command=query)
query_btn.grid(row=7, column=0, columnspan=2, pady=10, padx=10,ipadx=137)

# Commit Changes
conn.commit()


# Close connection
conn.close()

root.mainloop()
# Out:
# [('sdfs', 'sfds', 'we', 'rggawew', 'adgass', 'art', 1), ('wer', 'sfsef', 'sdfs', 'sfes', 'es', 'wer', 2)]
# [('sdfs', 'sfds', 'we', 'rggawew', 'adgass', 'art', 1), ('wer', 'sfsef', 'sdfs', 'sfes', 'es', 'wer', 2)]

# %%
from tkinter import *
from PIL import ImageTk, Image
import sqlite3


#sqlite has only 5 datatypes texts, integers, a real, null and blobs 

root = Tk()
root.title('Using databases')
iconpath = r"\Users\KIIT\Desktop\5th sem materials\Project\python_squre_icon_icon_257067.ico"
root.iconbitmap(iconpath)
root.geometry("600x400")


# Databases


# Create a databasee or connect to one
conn = sqlite3.connect('address_book.db')


# Create a cursor 
c = conn.cursor()

# Create a Table
#we commented out the table because we don't need to create the 
#table again and again once it is created 
'''
c.execute("""CREATE TABLE addresses(
first_name text, 
last_name text, 
address text,
city text, 
state text, 
zipcode integer)

""")
'''
# Create submit function for database
def submit():
    # Create a databasee or connect to one
    conn = sqlite3.connect('address_book.db')


    # Create a cursor 
    c = conn.cursor()
    
    #insert into table
    c.execute('INSERT INTO addresses VALUES(:f_name,:l_name,:addre,:city,:state,:zipc  )',
             {
                 'f_name':f_name.get(),
                 'l_name':l_name.get(),
                 'addre':addre.get(),
                 'city':city.get(),
                 'state':state.get(),
                 'zipc':zipc.get()
             })

    # Commit Changes
    conn.commit()


    # Close connection
    conn.close()
    
    
    
    
    
    
    # Clear the text Boxes
    f_name.delete(0, END)
    l_name.delete(0, END)
    addre.delete(0, END)
    city.delete(0, END)
    state.delete(0, END)
    zipc.delete(0, END)

    
    
    
# Create query function
def query():
    # Create a databasee or connect to one
    conn = sqlite3.connect('address_book.db')


    # Create a cursor 
    c = conn.cursor()
    
    # Query the database
    c.execute('SELECT *, oid FROM addresses')
    records = c.fetchall()
 #  print(records)
    #fetchone, fetchmany
    # LOOP thorugh results
    print_records = ''
    for record in records:
        print_records += str(record [0]) + " "+str(record [1])+'\n'
        
    query_label = Label(root, text=print_records)
    query_label.grid(row=8, column=0, columnspan=3)
        
        
        
     # Commit Changes
    conn.commit()


    # Close connection
    conn.close()
    
    return 



# Create text boxes
f_name = Entry(root, width=30)
f_name.grid(row=0,column=1, padx=20)
l_name = Entry(root, width=30)
l_name.grid(row=1,column=1, padx=20)
addre = Entry(root, width=30)
addre.grid(row=2,column=1, padx=20)
city = Entry(root, width=30)
city.grid(row=3,column=1, padx=20)
state = Entry(root, width=30)
state.grid(row=4,column=1, padx=20)
zipc = Entry(root, width=30)
zipc.grid(row=5,column=1, padx=20)

# Create text box label

f_name_lbl = Label(root, text='First Name')
f_name_lbl.grid(row=0, column=0)
l_name_lbl = Label(root, text='Last Name')
l_name_lbl.grid(row=1, column=0)
addre_lbl = Label(root, text='Address')
addre_lbl.grid(row=2, column=0)
city_lbl = Label(root, text='City')
city_lbl.grid(row=3, column=0)
state_lbl = Label(root, text='State')
state_lbl.grid(row=4, column=0)
zipc_lbl = Label(root, text='Zipcode')
zipc_lbl.grid(row=5, column=0)


# Create Submit Button
submit_btn = Button(root, text='Add record to database', command=submit)
submit_btn.grid(row=6, column=0,columnspan=2, pady=10, padx=10, ipadx=100)

# Query  button 
query_btn = Button(root, text='Show records',command=query)
query_btn.grid(row=7, column=0, columnspan=2, pady=10, padx=10,ipadx=137)

# Commit Changes
conn.commit()


# Close connection
conn.close()

root.mainloop()
